# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data = pd.read_csv("student-mat.csv", sep=';')
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
data['pass'] = data['G3'].apply(lambda x: 1 if x >= 10 else 0)
data.drop('G3', axis=1, inplace=True)

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
X = data.drop('pass', axis=1)
y = data['pass']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential()

model.add(Dense(16, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.1
)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6573 - loss: 0.6432 - val_accuracy: 0.5714 - val_loss: 0.6991
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6895 - loss: 0.5921 - val_accuracy: 0.5714 - val_loss: 0.6925
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7298 - loss: 0.5511 - val_accuracy: 0.6071 - val_loss: 0.6785
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7581 - loss: 0.5163 - val_accuracy: 0.6071 - val_loss: 0.6708
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7823 - loss: 0.4828 - val_accuracy: 0.6071 - val_loss: 0.6564
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8226 - loss: 0.4524 - val_accuracy: 0.6071 - val_loss: 0.6454
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8589 - loss: 0.4252 - val_accuracy: 0.6429 - val_loss: 0.6300
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8629 - loss: 0.3974 - val_accuracy: 0.6429 - val_loss: 0.6166
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8750 - loss: 0.3717 - val_accuracy: 0.6429 - val_loss: 0.6045
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8911 - loss: 0.3467 - val_accuracy: 0.6429 - val_loss: 0.5922
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8871 - loss: 0.3250 - val_accuracy: 0.6786 - val_loss: 0.5706
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8952 - loss: 0.3014 - val_accuracy: 0.7143 - val_loss: 0.5610
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9032 - loss: 0.2823 - val_accuracy: 0.7143 - val_loss: 0.5536
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9113 - loss: 0.2638 - val_accuracy: 0.7143 - val_loss: 0.5363
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9113 - loss: 0.2485 - val_accuracy: 0.7500 - val_loss: 0.5306
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9194 - loss: 0.2339 - val_accuracy: 0.7500 - val_loss: 0.5185
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9315 - loss: 0.2212 - val_accuracy: 0.7500 - val_loss: 0.5167
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9395 - loss: 0.2095 - val_accuracy: 0.7500 - val_loss: 0.5153
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9395 - loss: 0.1984 - val_accuracy: 0.7500 - val_loss: 0.5098
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9395 - loss: 0.1890 - val_accuracy: 0.7857 - val_loss: 0.5083
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9435 - loss: 0.1793 - val_accuracy: 0.7857 - val_loss: 0.4975
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9476 - loss: 0.1711 - val_accuracy: 0.7857 - val_loss: 0.5044
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9476 - loss: 0.1623 - val_accuracy: 0.7857 - val_loss: 0.4978
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9516 - loss: 0.1541 - val_accuracy: 0.7857 - val_loss: 0.5041
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1463 - val_accuracy: 0.7857 - val_loss: 0.4947
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1391 - val_accuracy: 0.7857 - val_loss: 0.5059
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.1330 - val_accuracy: 0.7857 - val_loss: 0.4957
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9677 - loss: 0.1261 - val_accuracy: 0.7857 - val_loss: 0.5095
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1200 - val_accuracy: 0.7857 - val_loss: 0.5093
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1148 - val_accuracy: 0.7857 - val_loss: 0.5123
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1095 - val_accuracy: 0.7857 - val_loss: 0.5204
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1046 - val_accuracy: 0.8214 - val_loss: 0.5145
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.0999 - val_accuracy: 0.7857 - val_loss: 0.5315
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9798 - loss: 0.0950 - val_accuracy: 0.8214 - val_loss: 0.5238
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0904 - val_accuracy: 0.8214 - val_loss: 0.5200
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0863 - val_accuracy: 0.8214 - val_loss: 0.5302
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0818 - val_accuracy: 0.8214 - val_loss: 0.5322
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9798 - loss: 0.0772 - val_accuracy: 0.8214 - val_loss: 0.5353
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0731 - val_accuracy: 0.8214 - val_loss: 0.5400
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0684 - val_accuracy: 0.8214 - val_loss: 0.5326
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0641 - val_accuracy: 0.8214 - val_loss: 0.5459
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0603 - val_accuracy: 0.8214 - val_loss: 0.5406
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0565 - val_accuracy: 0.8214 - val_loss: 0.5442
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0535 - val_accuracy: 0.8214 - val_loss: 0.5483
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0502 - val_accuracy: 0.8214 - val_loss: 0.5566
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0474 - val_accuracy: 0.8214 - val_loss: 0.5623
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0454 - val_accuracy: 0.8571 - val_loss: 0.5666
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0425 - val_accuracy: 0.8571 - val_loss: 0.5719
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0405 - val_accuracy: 0.8571 - val_loss: 0.5762
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0385 - val_accuracy: 0.8571 - val_loss: 0.5925

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Accuracy: 0.8907563025210085
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85        46
#            1       0.88      0.95      0.91        73
#
#     accuracy                           0.89       119
#    macro avg       0.89      0.87      0.88       119
# weighted avg       0.89      0.89      0.89       119
#
#
# Confusion Matrix:
# [[37  9]
#  [ 4 69]]
